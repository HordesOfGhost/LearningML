# %%
import pandas as pd

# %% [markdown]
# <h1>PreProcessing</h1>

# %%
df=pd.read_csv('mammographic_masses.data.txt')

# %%
df = pd.read_csv('mammographic_masses.data.txt', na_values=['?'], names = ['BI-RADS', 'age', 'shape', 'margin', 'density', 'severity'])
df.head()
# Out:
#    BI-RADS   age  shape  margin  density  severity
# 0      5.0  67.0    3.0     5.0      3.0         1
# 1      4.0  43.0    1.0     1.0      NaN         1
# 2      5.0  58.0    4.0     5.0      3.0         1
# 3      4.0  28.0    1.0     1.0      3.0         0
# 4      5.0  74.0    1.0     5.0      NaN         1

# %%
df.isna().sum()
# Out:
# BI-RADS      2
# age          5
# shape       31
# margin      48
# density     76
# severity     0
# dtype: int64

# %% [markdown]
# <h2>Data Cleaning</h2>

# %%
col=list(df.columns)
col
# Out:
# ['BI-RADS', 'age', 'shape', 'margin', 'density', 'severity']

# %%
for i in range(len(col)):
    print(f"Median for {i}:",df[col[i]].median())
# Out:
# Median for 0: 4.0
# Median for 1: 57.0
# Median for 2: 3.0
# Median for 3: 3.0
# Median for 4: 3.0
# Median for 5: 0.0

# %% [markdown]
# <h2>Filling with medians</h2>

# %%
for i in range(len(col)):
    df[col[i]].fillna(df[col[i]].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# BI-RADS     0
# age         0
# shape       0
# margin      0
# density     0
# severity    0
# dtype: int64

# %%
df.head()
# Out:
#    BI-RADS   age  shape  margin  density  severity
# 0      5.0  67.0    3.0     5.0      3.0         1
# 1      4.0  43.0    1.0     1.0      3.0         1
# 2      5.0  58.0    4.0     5.0      3.0         1
# 3      4.0  28.0    1.0     1.0      3.0         0
# 4      5.0  74.0    1.0     5.0      3.0         1

# %%
df.drop('BI-RADS',axis=1,inplace=True)

# %% [markdown]
# <h3>Splitting x and y </h3>

# %%
x=df.iloc[:,:-1].values
y=df.loc[:,'severity'].values

# %% [markdown]
# <h2>Normalization</h2>

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.79698441,  0.22038395,  1.43676223,  0.22480407],
#        [-0.86561042, -1.41505218, -1.18321596,  0.22480407],
#        [ 0.17351135,  1.03810202,  1.43676223,  0.22480407],
#        ...,
#        [ 0.58916006,  1.03810202,  1.43676223,  0.22480407],
#        [ 0.72770962,  1.03810202,  1.43676223,  0.22480407],
#        [ 0.45061049,  0.22038395,  0.12677314,  0.22480407]])

# %% [markdown]
# <h3>Visualizing</h3>

# %%
from Detailed_Details import Detailed_Details

# %%
df.head()
# Out:
#     age  shape  margin  density  severity
# 0  67.0    3.0     5.0      3.0         1
# 1  43.0    1.0     1.0      3.0         1
# 2  58.0    4.0     5.0      3.0         1
# 3  28.0    1.0     1.0      3.0         0
# 4  74.0    1.0     5.0      3.0         1

# %%
for i in range(1,len(col)-1):
    Detailed_Details(df,col[i],'severity',7)
# Out:
# <h3><center>Comparing age With severity</center></h3>Total Features 961<br>Mean of age = 55.5<br><center><table cellpadding=15><tr><td><center>age</center> </td> <td>Total No. <br>(age)</td> <td> Percentage <br>(age) </td><td>Total Outcome<br>(0)</td><td>Percentage Outcome<br>(0)<td>Total Outcome<br>(1)</td><td>Percentage Outcome<br>(1)</td></tr><tr><td>Greater Than Mean</td><td>510</td><td>53.07</td><td>192</td><td>37.21 %</td><td>318</td><td>71.46 %</td><tr><td>Less Than Mean</td><td>451</td><td>46.93</td><td>324</td><td>62.79 %</td><td>127</td><td>28.54 %</td></table></center>
# <h3><center>Comparing shape With severity</center></h3>Total Features 961  <br><center><table cellpadding=15><tr><td>shape</td> <td>Total No. (shape)</td> <td> Percentage (shape) </td><td>Total severity<br>(0)</td> <td>Percentage severity<br>(0)</td> <td>Total severity<br>(1)</td> <td>Percentage severity<br>(1)</td> </tr><tr><td></center>1.0</center></td><td>224</td><td>23.31%</td><td>186</td><td>83.04%</td><td>38</td><td>16.96%</td></tr><tr><td></center>2.0</center></td><td>211</td><td>21.96%</td><td>176</td><td>83.41%</td><td>35</td><td>16.59%</td></tr><tr><td></center>3.0</center></td><td>126</td><td>13.11%</td><td>69</td><td>54.76%</td><td>57</td><td>45.24%</td></tr><tr><td></center>4.0</center></td><td>400</td><td>41.62%</td><td>85</td><td>21.25%</td><td>315</td><td>78.75%</td></tr><table></center>
# <h3><center>Comparing margin With severity</center></h3>Total Features 961  <br><center><table cellpadding=15><tr><td>margin</td> <td>Total No. (margin)</td> <td> Percentage (margin) </td><td>Total severity<br>(0)</td> <td>Percentage severity<br>(0)</td> <td>Total severity<br>(1)</td> <td>Percentage severity<br>(1)</td> </tr><tr><td></center>1.0</center></td><td>357</td><td>37.15%</td><td>316</td><td>88.52%</td><td>41</td><td>11.48%</td></tr><tr><td></center>2.0</center></td><td>24</td><td>2.5%</td><td>9</td><td>37.5%</td><td>15</td><td>62.5%</td></tr><tr><td></center>3.0</center></td><td>164</td><td>17.07%</td><td>80</td><td>48.78%</td><td>84</td><td>51.22%</td></tr><tr><td></center>4.0</center></td><td>280</td><td>29.14%</td><td>89</td><td>31.79%</td><td>191</td><td>68.21%</td></tr><tr><td></center>5.0</center></td><td>136</td><td>14.15%</td><td>22</td><td>16.18%</td><td>114</td><td>83.82%</td></tr><table></center>
# <h3><center>Comparing density With severity</center></h3>Total Features 961  <br><center><table cellpadding=15><tr><td>density</td> <td>Total No. (density)</td> <td> Percentage (density) </td><td>Total severity<br>(0)</td> <td>Percentage severity<br>(0)</td> <td>Total severity<br>(1)</td> <td>Percentage severity<br>(1)</td> </tr><tr><td></center>1.0</center></td><td>16</td><td>1.66%</td><td>9</td><td>56.25%</td><td>7</td><td>43.75%</td></tr><tr><td></center>2.0</center></td><td>59</td><td>6.14%</td><td>41</td><td>69.49%</td><td>18</td><td>30.51%</td></tr><tr><td></center>3.0</center></td><td>874</td><td>90.95%</td><td>459</td><td>52.52%</td><td>415</td><td>47.48%</td></tr><tr><td></center>4.0</center></td><td>12</td><td>1.25%</td><td>7</td><td>58.33%</td><td>5</td><td>41.67%</td></tr><table></center>

# %%
df.corr()
# Out:
#                age     shape    margin   density  severity
# age       1.000000  0.360532  0.402995  0.021119  0.431329
# shape     0.360532  1.000000  0.718893  0.057495  0.552781
# margin    0.402995  0.718893  1.000000  0.094516  0.557867
# density   0.021119  0.057495  0.094516  1.000000  0.054681
# severity  0.431329  0.552781  0.557867  0.054681  1.000000

# %% [markdown]
# <h3>Train with GridSearch</h3>

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
params={
    'knn': {'n_neighbors':[3,5,7,9,11,13,15],
    'metric':['cosine','euclidean','manhattan'],
    'weights':['uniform','distance']},
    
    'svc': {
    'C':[0.1,1,10,100], 
    'gamma':[1,0.1,0.01,0.01], 
    'kernel':['rbf','linear']},
    
    'dtc':{
        'criterion':['gini','entropy'],
        'max_depth':[2,4,6,8,10,12]
    },
    
    'nb':{
        'priors': [None],
    'var_smoothing': [0.00000001, 0.000000001, 0.00000001]
    },
    'rf':{
        'criterion':['gini','entropy'],
        'max_depth':[2,4,6,8,10,12]
    },
    'lr':{
        'solver':[ 'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    }
}

# %%
#Now Finally Implementing Machine Learning
svc=SVC()
knn=KNeighborsClassifier()
dtc=DecisionTreeClassifier()
nb=GaussianNB()
rf=RandomForestClassifier()
lr=LogisticRegression()

# %%
models={'svc':svc,'knn':knn,'dtc':dtc,'nb':nb,'rf':rf,'lr':lr}

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
model_accuracy={}
score=0.0001
for model in models.keys():
        
    mod = GridSearchCV(
        models[model],
        params[model],
        verbose=0, #Progress bar showing
        cv=20, #cross validation
        n_jobs=-1, #cores to assign
    )
        
    gridsearch_result=mod.fit(x_train,y_train)
    predict=mod.predict(x_test)
    print(f"{model} : ",gridsearch_result.best_estimator_)
    print(f"{model}")
    print(confusion_matrix(predict,y_test))
        
    if(score < float(gridsearch_result.score(x_test,y_test))):
        score=gridsearch_result.score(x_test,y_test)
        gridsearch=gridsearch_result.fit(x_train,y_train)
    if model not in model_accuracy.keys():
        model_accuracy.update({model:gridsearch_result.score(x_test,y_test)})
# Out:
# svc :  SVC(C=100, gamma=0.01)
# svc
# [[83 15]
#  [18 77]]
# knn :  KNeighborsClassifier(metric='manhattan', n_neighbors=15)
# knn
# [[83 16]
#  [18 76]]
# dtc :  DecisionTreeClassifier(max_depth=2)
# dtc
# [[73 12]
#  [28 80]]
# nb :  GaussianNB(var_smoothing=1e-08)
# nb
# [[77 12]
#  [24 80]]
# rf :  RandomForestClassifier(max_depth=2)
# rf
# [[82 14]
#  [19 78]]
# lr :  LogisticRegression(solver='newton-cg')
# lr
# [[83 15]
#  [18 77]]

# %%
model_accuracy
# Out:
# {'svc': 0.8290155440414507,
#  'knn': 0.8238341968911918,
#  'dtc': 0.7927461139896373,
#  'nb': 0.8134715025906736,
#  'rf': 0.8290155440414507,
#  'lr': 0.8290155440414507}

# %%
gridsearch.best_estimator_
# Out:
# SVC(C=100, gamma=0.01)

# %% [markdown]
# <h2>Droping less correlated columns</h2>

# %%
df.corr()
# Out:
#                age     shape    margin   density  severity
# age       1.000000  0.360532  0.402995  0.021119  0.431329
# shape     0.360532  1.000000  0.718893  0.057495  0.552781
# margin    0.402995  0.718893  1.000000  0.094516  0.557867
# density   0.021119  0.057495  0.094516  1.000000  0.054681
# severity  0.431329  0.552781  0.557867  0.054681  1.000000

# %%
df_dropped=df.drop('density',axis=1)

# %%
df_dropped.head()
# Out:
#     age  shape  margin  severity
# 0  67.0    3.0     5.0         1
# 1  43.0    1.0     1.0         1
# 2  58.0    4.0     5.0         1
# 3  28.0    1.0     1.0         0
# 4  74.0    1.0     5.0         1

# %%
df_dropped.corr()
# Out:
#                age     shape    margin  severity
# age       1.000000  0.360532  0.402995  0.431329
# shape     0.360532  1.000000  0.718893  0.552781
# margin    0.402995  0.718893  1.000000  0.557867
# severity  0.431329  0.552781  0.557867  1.000000

# %%
x=df_dropped.iloc[:,:-1].values
y=df_dropped.loc[:,'severity'].values

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.79698441,  0.22038395,  1.43676223],
#        [-0.86561042, -1.41505218, -1.18321596],
#        [ 0.17351135,  1.03810202,  1.43676223],
#        ...,
#        [ 0.58916006,  1.03810202,  1.43676223],
#        [ 0.72770962,  1.03810202,  1.43676223],
#        [ 0.45061049,  0.22038395,  0.12677314]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
model_accuracy={}
score=0.0001
for model in models.keys():
        
    mod = GridSearchCV(
        models[model],
        params[model],
        verbose=0, #Progress bar showing
        cv=20, #cross validation
        n_jobs=-1, #cores to assign
    )
        
    gridsearch_result=mod.fit(x_train,y_train)
    predict=mod.predict(x_test)
    print(f"{model} : ",gridsearch_result.best_estimator_)
    print(f"{model}")
    print(confusion_matrix(predict,y_test))
        
    if(score < float(gridsearch_result.score(x_test,y_test))):
        score=gridsearch_result.score(x_test,y_test)
        gridsearch=gridsearch_result.fit(x_train,y_train)
    if model not in model_accuracy.keys():
        model_accuracy.update({model:gridsearch_result.score(x_test,y_test)})
# Out:
# svc :  SVC(C=0.1, gamma=1)
# svc
# [[84 14]
#  [17 78]]
# knn :  KNeighborsClassifier(metric='manhattan', n_neighbors=15)
# knn
# [[85 16]
#  [16 76]]
# dtc :  DecisionTreeClassifier(max_depth=2)
# dtc
# [[73 12]
#  [28 80]]
# nb :  GaussianNB(var_smoothing=1e-08)
# nb
# [[77 11]
#  [24 81]]
# rf :  RandomForestClassifier(max_depth=2)
# rf
# [[81 14]
#  [20 78]]
# lr :  LogisticRegression(solver='liblinear')
# lr
# [[83 15]
#  [18 77]]

# %%
model_accuracy
# Out:
# {'svc': 0.8393782383419689,
#  'knn': 0.8341968911917098,
#  'dtc': 0.7927461139896373,
#  'nb': 0.8186528497409327,
#  'rf': 0.8238341968911918,
#  'lr': 0.8290155440414507}

# %%
gridsearch.best_estimator_
# Out:
# SVC(C=0.1, gamma=1)

# %% [markdown]
# <h2>Using Neural Networks</h2>

# %%
x=df.iloc[:,:-1].values
y=df.loc[:,'severity'].values

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.79698441,  0.22038395,  1.43676223,  0.22480407],
#        [-0.86561042, -1.41505218, -1.18321596,  0.22480407],
#        [ 0.17351135,  1.03810202,  1.43676223,  0.22480407],
#        ...,
#        [ 0.58916006,  1.03810202,  1.43676223,  0.22480407],
#        [ 0.72770962,  1.03810202,  1.43676223,  0.22480407],
#        [ 0.45061049,  0.22038395,  0.12677314,  0.22480407]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
    #4 feature inputs going into an 6-unit layer (more does not seem to help - in fact you can go down to 4)
model.add(Dense(6, input_dim=4, kernel_initializer='normal', activation='relu'))
    # "Deep learning" turns out to be unnecessary - this additional hidden layer doesn't help either.
model.add(Dense(4, kernel_initializer='normal', activation='relu'))
    # Output layer with a binary classification (benign or malignant)
model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model; adam seemed to work best
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_scaled,y,verbose=2,epochs=200)
# Out:
# Epoch 1/200
# 31/31 - 0s - loss: 0.4593 - accuracy: 0.7992 - 203ms/epoch - 7ms/step
# Epoch 2/200
# 31/31 - 0s - loss: 0.4589 - accuracy: 0.7981 - 190ms/epoch - 6ms/step
# Epoch 3/200
# 31/31 - 0s - loss: 0.4586 - accuracy: 0.8012 - 188ms/epoch - 6ms/step
# Epoch 4/200
# 31/31 - 0s - loss: 0.4583 - accuracy: 0.8002 - 191ms/epoch - 6ms/step
# Epoch 5/200
# 31/31 - 0s - loss: 0.4581 - accuracy: 0.8012 - 190ms/epoch - 6ms/step
# Epoch 6/200
# 31/31 - 0s - loss: 0.4577 - accuracy: 0.8012 - 195ms/epoch - 6ms/step
# Epoch 7/200
# 31/31 - 0s - loss: 0.4576 - accuracy: 0.8012 - 186ms/epoch - 6ms/step
# Epoch 8/200
# 31/31 - 0s - loss: 0.4581 - accuracy: 0.8023 - 187ms/epoch - 6ms/step
# Epoch 9/200
# 31/31 - 0s - loss: 0.4578 - accuracy: 0.8033 - 195ms/epoch - 6ms/step
# Epoch 10/200
# 31/31 - 0s - loss: 0.4571 - accuracy: 0.8033 - 198ms/epoch - 6ms/step
# Epoch 11/200
# 31/31 - 0s - loss: 0.4568 - accuracy: 0.7992 - 182ms/epoch - 6ms/step
# Epoch 12/200
# 31/31 - 0s - loss: 0.4568 - accuracy: 0.8033 - 188ms/epoch - 6ms/step
# Epoch 13/200
# 31/31 - 0s - loss: 0.4566 - accuracy: 0.8023 - 208ms/epoch - 7ms/step
# Epoch 14/200
# 31/31 - 0s - loss: 0.4565 - accuracy: 0.8012 - 192ms/epoch - 6ms/step
# Epoch 15/200
# 31/31 - 0s - loss: 0.4562 - accuracy: 0.8023 - 203ms/epoch - 7ms/step
# Epoch 16/200
# 31/31 - 0s - loss: 0.4561 - accuracy: 0.7992 - 187ms/epoch - 6ms/step
# Epoch 17/200
# 31/31 - 0s - loss: 0.4559 - accuracy: 0.7950 - 195ms/epoch - 6ms/step
# Epoch 18/200
# 31/31 - 0s - loss: 0.4557 - accuracy: 0.7992 - 209ms/epoch - 7ms/step
# Epoch 19/200
# 31/31 - 0s - loss: 0.4561 - accuracy: 0.7960 - 187ms/epoch - 6ms/step
# Epoch 20/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7981 - 183ms/epoch - 6ms/step
# Epoch 21/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7981 - 194ms/epoch - 6ms/step
# Epoch 22/200
# 31/31 - 0s - loss: 0.4553 - accuracy: 0.7981 - 226ms/epoch - 7ms/step
# Epoch 23/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.8012 - 192ms/epoch - 6ms/step
# Epoch 24/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7981 - 172ms/epoch - 6ms/step
# Epoch 25/200
# 31/31 - 0s - loss: 0.4553 - accuracy: 0.8002 - 183ms/epoch - 6ms/step
# Epoch 26/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.8044 - 187ms/epoch - 6ms/step
# Epoch 27/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.8002 - 183ms/epoch - 6ms/step
# Epoch 28/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.8023 - 180ms/epoch - 6ms/step
# Epoch 29/200
# 31/31 - 0s - loss: 0.4548 - accuracy: 0.8012 - 179ms/epoch - 6ms/step
# Epoch 30/200
# 31/31 - 0s - loss: 0.4546 - accuracy: 0.8002 - 189ms/epoch - 6ms/step
# Epoch 31/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7971 - 180ms/epoch - 6ms/step
# Epoch 32/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7981 - 188ms/epoch - 6ms/step
# Epoch 33/200
# 31/31 - 0s - loss: 0.4557 - accuracy: 0.8002 - 179ms/epoch - 6ms/step
# Epoch 34/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.8002 - 180ms/epoch - 6ms/step
# Epoch 35/200
# 31/31 - 0s - loss: 0.4548 - accuracy: 0.8002 - 182ms/epoch - 6ms/step
# Epoch 36/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7981 - 178ms/epoch - 6ms/step
# Epoch 37/200
# 31/31 - 0s - loss: 0.4548 - accuracy: 0.7981 - 179ms/epoch - 6ms/step
# Epoch 38/200
# 31/31 - 0s - loss: 0.4559 - accuracy: 0.8012 - 177ms/epoch - 6ms/step
# Epoch 39/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7981 - 181ms/epoch - 6ms/step
# Epoch 40/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7992 - 184ms/epoch - 6ms/step
# Epoch 41/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7971 - 179ms/epoch - 6ms/step
# Epoch 42/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7971 - 182ms/epoch - 6ms/step
# Epoch 43/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7971 - 180ms/epoch - 6ms/step
# Epoch 44/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7992 - 178ms/epoch - 6ms/step
# Epoch 45/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7992 - 181ms/epoch - 6ms/step
# Epoch 46/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7992 - 187ms/epoch - 6ms/step
# Epoch 47/200
# 31/31 - 0s - loss: 0.4543 - accuracy: 0.7971 - 180ms/epoch - 6ms/step
# Epoch 48/200
# 31/31 - 0s - loss: 0.4543 - accuracy: 0.7992 - 176ms/epoch - 6ms/step
# Epoch 49/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7992 - 180ms/epoch - 6ms/step
# Epoch 50/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7981 - 178ms/epoch - 6ms/step
# Epoch 51/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7971 - 180ms/epoch - 6ms/step
# Epoch 52/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7960 - 178ms/epoch - 6ms/step
# Epoch 53/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7981 - 180ms/epoch - 6ms/step
# Epoch 54/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.8002 - 182ms/epoch - 6ms/step
# Epoch 55/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.8002 - 183ms/epoch - 6ms/step
# Epoch 56/200
# 31/31 - 0s - loss: 0.4540 - accuracy: 0.7992 - 179ms/epoch - 6ms/step
# Epoch 57/200
# 31/31 - 0s - loss: 0.4539 - accuracy: 0.7992 - 178ms/epoch - 6ms/step
# Epoch 58/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7971 - 177ms/epoch - 6ms/step
# Epoch 59/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7960 - 183ms/epoch - 6ms/step
# Epoch 60/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7981 - 176ms/epoch - 6ms/step
# Epoch 61/200
# 31/31 - 0s - loss: 0.4540 - accuracy: 0.7992 - 187ms/epoch - 6ms/step
# Epoch 62/200
# 31/31 - 0s - loss: 0.4540 - accuracy: 0.7981 - 187ms/epoch - 6ms/step
# Epoch 63/200
# 31/31 - 0s - loss: 0.4539 - accuracy: 0.8002 - 180ms/epoch - 6ms/step
# Epoch 64/200
# 31/31 - 0s - loss: 0.4540 - accuracy: 0.8002 - 183ms/epoch - 6ms/step
# Epoch 65/200
# 31/31 - 0s - loss: 0.4539 - accuracy: 0.8002 - 204ms/epoch - 7ms/step
# Epoch 66/200
# 31/31 - 0s - loss: 0.4537 - accuracy: 0.8002 - 218ms/epoch - 7ms/step
# Epoch 67/200
# 31/31 - 0s - loss: 0.4536 - accuracy: 0.7992 - 216ms/epoch - 7ms/step
# Epoch 68/200
# 31/31 - 0s - loss: 0.4538 - accuracy: 0.8002 - 206ms/epoch - 7ms/step
# Epoch 69/200
# 31/31 - 0s - loss: 0.4537 - accuracy: 0.7981 - 190ms/epoch - 6ms/step
# Epoch 70/200
# 31/31 - 0s - loss: 0.4536 - accuracy: 0.7981 - 197ms/epoch - 6ms/step
# Epoch 71/200
# 31/31 - 0s - loss: 0.4538 - accuracy: 0.8002 - 225ms/epoch - 7ms/step
# Epoch 72/200
# 31/31 - 0s - loss: 0.4535 - accuracy: 0.8002 - 231ms/epoch - 7ms/step
# Epoch 73/200
# 31/31 - 0s - loss: 0.4538 - accuracy: 0.7981 - 205ms/epoch - 7ms/step
# Epoch 74/200
# 31/31 - 0s - loss: 0.4539 - accuracy: 0.8002 - 213ms/epoch - 7ms/step
# Epoch 75/200
# 31/31 - 0s - loss: 0.4536 - accuracy: 0.7992 - 216ms/epoch - 7ms/step
# Epoch 76/200
# 31/31 - 0s - loss: 0.4536 - accuracy: 0.8012 - 207ms/epoch - 7ms/step
# Epoch 77/200
# 31/31 - 0s - loss: 0.4539 - accuracy: 0.8002 - 197ms/epoch - 6ms/step
# Epoch 78/200
# 31/31 - 0s - loss: 0.4538 - accuracy: 0.7992 - 196ms/epoch - 6ms/step
# Epoch 79/200
# 31/31 - 0s - loss: 0.4533 - accuracy: 0.7981 - 194ms/epoch - 6ms/step
# Epoch 80/200
# 31/31 - 0s - loss: 0.4536 - accuracy: 0.7992 - 192ms/epoch - 6ms/step
# Epoch 81/200
# 31/31 - 0s - loss: 0.4534 - accuracy: 0.7992 - 173ms/epoch - 6ms/step
# Epoch 82/200
# 31/31 - 0s - loss: 0.4535 - accuracy: 0.8002 - 180ms/epoch - 6ms/step
# Epoch 83/200
# 31/31 - 0s - loss: 0.4536 - accuracy: 0.8012 - 192ms/epoch - 6ms/step
# Epoch 84/200
# 31/31 - 0s - loss: 0.4534 - accuracy: 0.8023 - 163ms/epoch - 5ms/step
# Epoch 85/200
# 31/31 - 0s - loss: 0.4538 - accuracy: 0.8002 - 184ms/epoch - 6ms/step
# Epoch 86/200
# 31/31 - 0s - loss: 0.4533 - accuracy: 0.7992 - 202ms/epoch - 7ms/step
# Epoch 87/200
# 31/31 - 0s - loss: 0.4531 - accuracy: 0.7981 - 226ms/epoch - 7ms/step
# Epoch 88/200
# 31/31 - 0s - loss: 0.4530 - accuracy: 0.7992 - 205ms/epoch - 7ms/step
# Epoch 89/200
# 31/31 - 0s - loss: 0.4531 - accuracy: 0.7992 - 203ms/epoch - 7ms/step
# Epoch 90/200
# 31/31 - 0s - loss: 0.4530 - accuracy: 0.8002 - 188ms/epoch - 6ms/step
# Epoch 91/200
# 31/31 - 0s - loss: 0.4530 - accuracy: 0.8002 - 201ms/epoch - 6ms/step
# Epoch 92/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.8002 - 180ms/epoch - 6ms/step
# Epoch 93/200
# 31/31 - 0s - loss: 0.4529 - accuracy: 0.8023 - 197ms/epoch - 6ms/step
# Epoch 94/200
# 31/31 - 0s - loss: 0.4529 - accuracy: 0.8012 - 190ms/epoch - 6ms/step
# Epoch 95/200
# 31/31 - 0s - loss: 0.4529 - accuracy: 0.8002 - 184ms/epoch - 6ms/step
# Epoch 96/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.8012 - 194ms/epoch - 6ms/step
# Epoch 97/200
# 31/31 - 0s - loss: 0.4527 - accuracy: 0.8002 - 199ms/epoch - 6ms/step
# Epoch 98/200
# 31/31 - 0s - loss: 0.4530 - accuracy: 0.7992 - 200ms/epoch - 6ms/step
# Epoch 99/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.7992 - 188ms/epoch - 6ms/step
# Epoch 100/200
# 31/31 - 0s - loss: 0.4530 - accuracy: 0.8002 - 199ms/epoch - 6ms/step
# Epoch 101/200
# 31/31 - 0s - loss: 0.4531 - accuracy: 0.8033 - 197ms/epoch - 6ms/step
# Epoch 102/200
# 31/31 - 0s - loss: 0.4530 - accuracy: 0.8033 - 192ms/epoch - 6ms/step
# Epoch 103/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.8023 - 195ms/epoch - 6ms/step
# Epoch 104/200
# 31/31 - 0s - loss: 0.4533 - accuracy: 0.7992 - 200ms/epoch - 6ms/step
# Epoch 105/200
# 31/31 - 0s - loss: 0.4531 - accuracy: 0.8012 - 219ms/epoch - 7ms/step
# Epoch 106/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.8033 - 207ms/epoch - 7ms/step
# Epoch 107/200
# 31/31 - 0s - loss: 0.4527 - accuracy: 0.8023 - 198ms/epoch - 6ms/step
# Epoch 108/200
# 31/31 - 0s - loss: 0.4531 - accuracy: 0.8023 - 332ms/epoch - 11ms/step
# Epoch 109/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.8033 - 194ms/epoch - 6ms/step
# Epoch 110/200
# 31/31 - 0s - loss: 0.4527 - accuracy: 0.8033 - 202ms/epoch - 7ms/step
# Epoch 111/200
# 31/31 - 0s - loss: 0.4526 - accuracy: 0.8023 - 183ms/epoch - 6ms/step
# Epoch 112/200
# 31/31 - 0s - loss: 0.4526 - accuracy: 0.8033 - 182ms/epoch - 6ms/step
# Epoch 113/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.8033 - 185ms/epoch - 6ms/step
# Epoch 114/200
# 31/31 - 0s - loss: 0.4526 - accuracy: 0.8023 - 184ms/epoch - 6ms/step
# Epoch 115/200
# 31/31 - 0s - loss: 0.4524 - accuracy: 0.8023 - 185ms/epoch - 6ms/step
# Epoch 116/200
# 31/31 - 0s - loss: 0.4526 - accuracy: 0.8012 - 178ms/epoch - 6ms/step
# Epoch 117/200
# 31/31 - 0s - loss: 0.4526 - accuracy: 0.8023 - 178ms/epoch - 6ms/step
# Epoch 118/200
# 31/31 - 0s - loss: 0.4531 - accuracy: 0.7960 - 187ms/epoch - 6ms/step
# Epoch 119/200
# 31/31 - 0s - loss: 0.4532 - accuracy: 0.7981 - 184ms/epoch - 6ms/step
# Epoch 120/200
# 31/31 - 0s - loss: 0.4529 - accuracy: 0.7981 - 190ms/epoch - 6ms/step
# Epoch 121/200
# 31/31 - 0s - loss: 0.4526 - accuracy: 0.8012 - 185ms/epoch - 6ms/step
# Epoch 122/200
# 31/31 - 0s - loss: 0.4525 - accuracy: 0.8012 - 181ms/epoch - 6ms/step
# Epoch 123/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8012 - 186ms/epoch - 6ms/step
# Epoch 124/200
# 31/31 - 0s - loss: 0.4524 - accuracy: 0.7992 - 180ms/epoch - 6ms/step
# Epoch 125/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8023 - 186ms/epoch - 6ms/step
# Epoch 126/200
# 31/31 - 0s - loss: 0.4524 - accuracy: 0.8023 - 181ms/epoch - 6ms/step
# Epoch 127/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8033 - 183ms/epoch - 6ms/step
# Epoch 128/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8023 - 255ms/epoch - 8ms/step
# Epoch 129/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8023 - 199ms/epoch - 6ms/step
# Epoch 130/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8023 - 170ms/epoch - 5ms/step
# Epoch 131/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.7981 - 184ms/epoch - 6ms/step
# Epoch 132/200
# 31/31 - 0s - loss: 0.4528 - accuracy: 0.8002 - 193ms/epoch - 6ms/step
# Epoch 133/200
# 31/31 - 0s - loss: 0.4533 - accuracy: 0.8023 - 181ms/epoch - 6ms/step
# Epoch 134/200
# 31/31 - 0s - loss: 0.4527 - accuracy: 0.8023 - 199ms/epoch - 6ms/step
# Epoch 135/200
# 31/31 - 0s - loss: 0.4526 - accuracy: 0.8033 - 201ms/epoch - 6ms/step
# Epoch 136/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8012 - 207ms/epoch - 7ms/step
# Epoch 137/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.7992 - 183ms/epoch - 6ms/step
# Epoch 138/200
# 31/31 - 0s - loss: 0.4527 - accuracy: 0.7971 - 229ms/epoch - 7ms/step
# Epoch 139/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.7992 - 200ms/epoch - 6ms/step
# Epoch 140/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8012 - 189ms/epoch - 6ms/step
# Epoch 141/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8002 - 193ms/epoch - 6ms/step
# Epoch 142/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8012 - 199ms/epoch - 6ms/step
# Epoch 143/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8012 - 185ms/epoch - 6ms/step
# Epoch 144/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8023 - 186ms/epoch - 6ms/step
# Epoch 145/200
# 31/31 - 0s - loss: 0.4524 - accuracy: 0.8023 - 176ms/epoch - 6ms/step
# Epoch 146/200
# 31/31 - 0s - loss: 0.4524 - accuracy: 0.8033 - 205ms/epoch - 7ms/step
# Epoch 147/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.8012 - 213ms/epoch - 7ms/step
# Epoch 148/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8033 - 204ms/epoch - 7ms/step
# Epoch 149/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8012 - 166ms/epoch - 5ms/step
# Epoch 150/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8012 - 200ms/epoch - 6ms/step
# Epoch 151/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.8012 - 168ms/epoch - 5ms/step
# Epoch 152/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.7992 - 197ms/epoch - 6ms/step
# Epoch 153/200
# 31/31 - 0s - loss: 0.4524 - accuracy: 0.7981 - 191ms/epoch - 6ms/step
# Epoch 154/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.7971 - 191ms/epoch - 6ms/step
# Epoch 155/200
# 31/31 - 0s - loss: 0.4518 - accuracy: 0.7992 - 187ms/epoch - 6ms/step
# Epoch 156/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.7992 - 203ms/epoch - 7ms/step
# Epoch 157/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.7981 - 177ms/epoch - 6ms/step
# Epoch 158/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.8023 - 205ms/epoch - 7ms/step
# Epoch 159/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.8054 - 225ms/epoch - 7ms/step
# Epoch 160/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8033 - 209ms/epoch - 7ms/step
# Epoch 161/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.8033 - 220ms/epoch - 7ms/step
# Epoch 162/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8033 - 218ms/epoch - 7ms/step
# Epoch 163/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8012 - 216ms/epoch - 7ms/step
# Epoch 164/200
# 31/31 - 0s - loss: 0.4518 - accuracy: 0.8012 - 189ms/epoch - 6ms/step
# Epoch 165/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8023 - 173ms/epoch - 6ms/step
# Epoch 166/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8002 - 184ms/epoch - 6ms/step
# Epoch 167/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8044 - 201ms/epoch - 6ms/step
# Epoch 168/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8012 - 290ms/epoch - 9ms/step
# Epoch 169/200
# 31/31 - 0s - loss: 0.4524 - accuracy: 0.8044 - 191ms/epoch - 6ms/step
# Epoch 170/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.8044 - 198ms/epoch - 6ms/step
# Epoch 171/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.7981 - 195ms/epoch - 6ms/step
# Epoch 172/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.7992 - 190ms/epoch - 6ms/step
# Epoch 173/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8044 - 195ms/epoch - 6ms/step
# Epoch 174/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.8044 - 177ms/epoch - 6ms/step
# Epoch 175/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8002 - 179ms/epoch - 6ms/step
# Epoch 176/200
# 31/31 - 0s - loss: 0.4518 - accuracy: 0.8012 - 193ms/epoch - 6ms/step
# Epoch 177/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.8023 - 197ms/epoch - 6ms/step
# Epoch 178/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8054 - 197ms/epoch - 6ms/step
# Epoch 179/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.7992 - 198ms/epoch - 6ms/step
# Epoch 180/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8002 - 267ms/epoch - 9ms/step
# Epoch 181/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8033 - 302ms/epoch - 10ms/step
# Epoch 182/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.8044 - 226ms/epoch - 7ms/step
# Epoch 183/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.8033 - 172ms/epoch - 6ms/step
# Epoch 184/200
# 31/31 - 0s - loss: 0.4516 - accuracy: 0.8023 - 200ms/epoch - 6ms/step
# Epoch 185/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.8002 - 214ms/epoch - 7ms/step
# Epoch 186/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8033 - 223ms/epoch - 7ms/step
# Epoch 187/200
# 31/31 - 0s - loss: 0.4518 - accuracy: 0.8023 - 204ms/epoch - 7ms/step
# Epoch 188/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.8033 - 196ms/epoch - 6ms/step
# Epoch 189/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.8054 - 199ms/epoch - 6ms/step
# Epoch 190/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.8065 - 199ms/epoch - 6ms/step
# Epoch 191/200
# 31/31 - 0s - loss: 0.4523 - accuracy: 0.8075 - 192ms/epoch - 6ms/step
# Epoch 192/200
# 31/31 - 0s - loss: 0.4522 - accuracy: 0.8012 - 189ms/epoch - 6ms/step
# Epoch 193/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8023 - 182ms/epoch - 6ms/step
# Epoch 194/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8033 - 187ms/epoch - 6ms/step
# Epoch 195/200
# 31/31 - 0s - loss: 0.4521 - accuracy: 0.8044 - 236ms/epoch - 8ms/step
# Epoch 196/200
# 31/31 - 0s - loss: 0.4520 - accuracy: 0.8033 - 179ms/epoch - 6ms/step
# Epoch 197/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.8044 - 187ms/epoch - 6ms/step
# Epoch 198/200
# 31/31 - 0s - loss: 0.4519 - accuracy: 0.8054 - 196ms/epoch - 6ms/step
# Epoch 199/200
# 31/31 - 0s - loss: 0.4517 - accuracy: 0.8044 - 182ms/epoch - 6ms/step
# Epoch 200/200
# 31/31 - 0s - loss: 0.4516 - accuracy: 0.8054 - 198ms/epoch - 6ms/step

# %%
x=df_dropped.iloc[:,:-1].values
y=df_dropped.loc[:,'severity'].values

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.79698441,  0.22038395,  1.43676223],
#        [-0.86561042, -1.41505218, -1.18321596],
#        [ 0.17351135,  1.03810202,  1.43676223],
#        ...,
#        [ 0.58916006,  1.03810202,  1.43676223],
#        [ 0.72770962,  1.03810202,  1.43676223],
#        [ 0.45061049,  0.22038395,  0.12677314]])

# %%
model = Sequential()
    #4 feature inputs going into an 6-unit layer (more does not seem to help - in fact you can go down to 4)
model.add(Dense(6, input_dim=3, kernel_initializer='normal', activation='relu'))
    # "Deep learning" turns out to be unnecessary - this additional hidden layer doesn't help either.
model.add(Dense(4, kernel_initializer='normal', activation='relu'))
    # Output layer with a binary classification (benign or malignant)
model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model; adam seemed to work best
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_scaled,y,verbose=2,epochs=200)
# Out:
# Epoch 1/200
# 31/31 - 1s - loss: 0.6925 - accuracy: 0.5317 - 685ms/epoch - 22ms/step
# Epoch 2/200
# 31/31 - 0s - loss: 0.6887 - accuracy: 0.5369 - 195ms/epoch - 6ms/step
# Epoch 3/200
# 31/31 - 0s - loss: 0.6775 - accuracy: 0.5494 - 188ms/epoch - 6ms/step
# Epoch 4/200
# 31/31 - 0s - loss: 0.6510 - accuracy: 0.7482 - 196ms/epoch - 6ms/step
# Epoch 5/200
# 31/31 - 0s - loss: 0.6097 - accuracy: 0.7867 - 206ms/epoch - 7ms/step
# Epoch 6/200
# 31/31 - 0s - loss: 0.5694 - accuracy: 0.7898 - 190ms/epoch - 6ms/step
# Epoch 7/200
# 31/31 - 0s - loss: 0.5416 - accuracy: 0.7908 - 212ms/epoch - 7ms/step
# Epoch 8/200
# 31/31 - 0s - loss: 0.5230 - accuracy: 0.7950 - 185ms/epoch - 6ms/step
# Epoch 9/200
# 31/31 - 0s - loss: 0.5091 - accuracy: 0.7960 - 206ms/epoch - 7ms/step
# Epoch 10/200
# 31/31 - 0s - loss: 0.4990 - accuracy: 0.7908 - 185ms/epoch - 6ms/step
# Epoch 11/200
# 31/31 - 0s - loss: 0.4901 - accuracy: 0.7919 - 190ms/epoch - 6ms/step
# Epoch 12/200
# 31/31 - 0s - loss: 0.4825 - accuracy: 0.7940 - 222ms/epoch - 7ms/step
# Epoch 13/200
# 31/31 - 0s - loss: 0.4776 - accuracy: 0.7950 - 195ms/epoch - 6ms/step
# Epoch 14/200
# 31/31 - 0s - loss: 0.4731 - accuracy: 0.7960 - 208ms/epoch - 7ms/step
# Epoch 15/200
# 31/31 - 0s - loss: 0.4701 - accuracy: 0.7971 - 187ms/epoch - 6ms/step
# Epoch 16/200
# 31/31 - 0s - loss: 0.4672 - accuracy: 0.7950 - 212ms/epoch - 7ms/step
# Epoch 17/200
# 31/31 - 0s - loss: 0.4660 - accuracy: 0.7960 - 213ms/epoch - 7ms/step
# Epoch 18/200
# 31/31 - 0s - loss: 0.4644 - accuracy: 0.7950 - 190ms/epoch - 6ms/step
# Epoch 19/200
# 31/31 - 0s - loss: 0.4628 - accuracy: 0.7950 - 213ms/epoch - 7ms/step
# Epoch 20/200
# 31/31 - 0s - loss: 0.4621 - accuracy: 0.7971 - 195ms/epoch - 6ms/step
# Epoch 21/200
# 31/31 - 0s - loss: 0.4613 - accuracy: 0.7971 - 186ms/epoch - 6ms/step
# Epoch 22/200
# 31/31 - 0s - loss: 0.4610 - accuracy: 0.7992 - 190ms/epoch - 6ms/step
# Epoch 23/200
# 31/31 - 0s - loss: 0.4601 - accuracy: 0.7992 - 187ms/epoch - 6ms/step
# Epoch 24/200
# 31/31 - 0s - loss: 0.4602 - accuracy: 0.7950 - 181ms/epoch - 6ms/step
# Epoch 25/200
# 31/31 - 0s - loss: 0.4596 - accuracy: 0.7971 - 185ms/epoch - 6ms/step
# Epoch 26/200
# 31/31 - 0s - loss: 0.4596 - accuracy: 0.8012 - 182ms/epoch - 6ms/step
# Epoch 27/200
# 31/31 - 0s - loss: 0.4596 - accuracy: 0.8002 - 187ms/epoch - 6ms/step
# Epoch 28/200
# 31/31 - 0s - loss: 0.4590 - accuracy: 0.7981 - 190ms/epoch - 6ms/step
# Epoch 29/200
# 31/31 - 0s - loss: 0.4584 - accuracy: 0.7981 - 180ms/epoch - 6ms/step
# Epoch 30/200
# 31/31 - 0s - loss: 0.4584 - accuracy: 0.7971 - 186ms/epoch - 6ms/step
# Epoch 31/200
# 31/31 - 0s - loss: 0.4580 - accuracy: 0.7981 - 189ms/epoch - 6ms/step
# Epoch 32/200
# 31/31 - 0s - loss: 0.4578 - accuracy: 0.7981 - 190ms/epoch - 6ms/step
# Epoch 33/200
# 31/31 - 0s - loss: 0.4578 - accuracy: 0.7960 - 184ms/epoch - 6ms/step
# Epoch 34/200
# 31/31 - 0s - loss: 0.4576 - accuracy: 0.7950 - 183ms/epoch - 6ms/step
# Epoch 35/200
# 31/31 - 0s - loss: 0.4574 - accuracy: 0.7960 - 190ms/epoch - 6ms/step
# Epoch 36/200
# 31/31 - 0s - loss: 0.4574 - accuracy: 0.7981 - 185ms/epoch - 6ms/step
# Epoch 37/200
# 31/31 - 0s - loss: 0.4571 - accuracy: 0.7950 - 190ms/epoch - 6ms/step
# Epoch 38/200
# 31/31 - 0s - loss: 0.4570 - accuracy: 0.7950 - 175ms/epoch - 6ms/step
# Epoch 39/200
# 31/31 - 0s - loss: 0.4571 - accuracy: 0.7981 - 181ms/epoch - 6ms/step
# Epoch 40/200
# 31/31 - 0s - loss: 0.4573 - accuracy: 0.7971 - 190ms/epoch - 6ms/step
# Epoch 41/200
# 31/31 - 0s - loss: 0.4569 - accuracy: 0.7950 - 184ms/epoch - 6ms/step
# Epoch 42/200
# 31/31 - 0s - loss: 0.4573 - accuracy: 0.7950 - 189ms/epoch - 6ms/step
# Epoch 43/200
# 31/31 - 0s - loss: 0.4568 - accuracy: 0.7950 - 184ms/epoch - 6ms/step
# Epoch 44/200
# 31/31 - 0s - loss: 0.4565 - accuracy: 0.7940 - 183ms/epoch - 6ms/step
# Epoch 45/200
# 31/31 - 0s - loss: 0.4571 - accuracy: 0.7919 - 182ms/epoch - 6ms/step
# Epoch 46/200
# 31/31 - 0s - loss: 0.4572 - accuracy: 0.7919 - 179ms/epoch - 6ms/step
# Epoch 47/200
# 31/31 - 0s - loss: 0.4568 - accuracy: 0.7919 - 172ms/epoch - 6ms/step
# Epoch 48/200
# 31/31 - 0s - loss: 0.4565 - accuracy: 0.7950 - 181ms/epoch - 6ms/step
# Epoch 49/200
# 31/31 - 0s - loss: 0.4565 - accuracy: 0.7960 - 185ms/epoch - 6ms/step
# Epoch 50/200
# 31/31 - 0s - loss: 0.4565 - accuracy: 0.7950 - 196ms/epoch - 6ms/step
# Epoch 51/200
# 31/31 - 0s - loss: 0.4567 - accuracy: 0.7888 - 205ms/epoch - 7ms/step
# Epoch 52/200
# 31/31 - 0s - loss: 0.4564 - accuracy: 0.7919 - 187ms/epoch - 6ms/step
# Epoch 53/200
# 31/31 - 0s - loss: 0.4561 - accuracy: 0.7919 - 200ms/epoch - 6ms/step
# Epoch 54/200
# 31/31 - 0s - loss: 0.4563 - accuracy: 0.7908 - 185ms/epoch - 6ms/step
# Epoch 55/200
# 31/31 - 0s - loss: 0.4563 - accuracy: 0.7919 - 213ms/epoch - 7ms/step
# Epoch 56/200
# 31/31 - 0s - loss: 0.4561 - accuracy: 0.7919 - 245ms/epoch - 8ms/step
# Epoch 57/200
# 31/31 - 0s - loss: 0.4561 - accuracy: 0.7919 - 179ms/epoch - 6ms/step
# Epoch 58/200
# 31/31 - 0s - loss: 0.4564 - accuracy: 0.7940 - 200ms/epoch - 6ms/step
# Epoch 59/200
# 31/31 - 0s - loss: 0.4562 - accuracy: 0.7971 - 179ms/epoch - 6ms/step
# Epoch 60/200
# 31/31 - 0s - loss: 0.4568 - accuracy: 0.7971 - 195ms/epoch - 6ms/step
# Epoch 61/200
# 31/31 - 0s - loss: 0.4563 - accuracy: 0.7971 - 198ms/epoch - 6ms/step
# Epoch 62/200
# 31/31 - 0s - loss: 0.4564 - accuracy: 0.7929 - 209ms/epoch - 7ms/step
# Epoch 63/200
# 31/31 - 0s - loss: 0.4564 - accuracy: 0.7929 - 187ms/epoch - 6ms/step
# Epoch 64/200
# 31/31 - 0s - loss: 0.4563 - accuracy: 0.7929 - 192ms/epoch - 6ms/step
# Epoch 65/200
# 31/31 - 0s - loss: 0.4563 - accuracy: 0.7950 - 189ms/epoch - 6ms/step
# Epoch 66/200
# 31/31 - 0s - loss: 0.4561 - accuracy: 0.7950 - 176ms/epoch - 6ms/step
# Epoch 67/200
# 31/31 - 0s - loss: 0.4563 - accuracy: 0.7940 - 179ms/epoch - 6ms/step
# Epoch 68/200
# 31/31 - 0s - loss: 0.4561 - accuracy: 0.7950 - 182ms/epoch - 6ms/step
# Epoch 69/200
# 31/31 - 0s - loss: 0.4560 - accuracy: 0.7950 - 177ms/epoch - 6ms/step
# Epoch 70/200
# 31/31 - 0s - loss: 0.4564 - accuracy: 0.7971 - 180ms/epoch - 6ms/step
# Epoch 71/200
# 31/31 - 0s - loss: 0.4566 - accuracy: 0.7960 - 179ms/epoch - 6ms/step
# Epoch 72/200
# 31/31 - 0s - loss: 0.4560 - accuracy: 0.7971 - 172ms/epoch - 6ms/step
# Epoch 73/200
# 31/31 - 0s - loss: 0.4557 - accuracy: 0.7950 - 173ms/epoch - 6ms/step
# Epoch 74/200
# 31/31 - 0s - loss: 0.4557 - accuracy: 0.7950 - 183ms/epoch - 6ms/step
# Epoch 75/200
# 31/31 - 0s - loss: 0.4559 - accuracy: 0.7950 - 172ms/epoch - 6ms/step
# Epoch 76/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7950 - 174ms/epoch - 6ms/step
# Epoch 77/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7940 - 178ms/epoch - 6ms/step
# Epoch 78/200
# 31/31 - 0s - loss: 0.4558 - accuracy: 0.7908 - 174ms/epoch - 6ms/step
# Epoch 79/200
# 31/31 - 0s - loss: 0.4556 - accuracy: 0.7919 - 176ms/epoch - 6ms/step
# Epoch 80/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.7929 - 178ms/epoch - 6ms/step
# Epoch 81/200
# 31/31 - 0s - loss: 0.4556 - accuracy: 0.7940 - 181ms/epoch - 6ms/step
# Epoch 82/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.7950 - 183ms/epoch - 6ms/step
# Epoch 83/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.7950 - 175ms/epoch - 6ms/step
# Epoch 84/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7940 - 186ms/epoch - 6ms/step
# Epoch 85/200
# 31/31 - 0s - loss: 0.4556 - accuracy: 0.7940 - 186ms/epoch - 6ms/step
# Epoch 86/200
# 31/31 - 0s - loss: 0.4560 - accuracy: 0.7908 - 184ms/epoch - 6ms/step
# Epoch 87/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7919 - 177ms/epoch - 6ms/step
# Epoch 88/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7950 - 178ms/epoch - 6ms/step
# Epoch 89/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7940 - 183ms/epoch - 6ms/step
# Epoch 90/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7950 - 188ms/epoch - 6ms/step
# Epoch 91/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7940 - 179ms/epoch - 6ms/step
# Epoch 92/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.7940 - 186ms/epoch - 6ms/step
# Epoch 93/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7940 - 187ms/epoch - 6ms/step
# Epoch 94/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7908 - 173ms/epoch - 6ms/step
# Epoch 95/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7919 - 171ms/epoch - 6ms/step
# Epoch 96/200
# 31/31 - 0s - loss: 0.4556 - accuracy: 0.7950 - 182ms/epoch - 6ms/step
# Epoch 97/200
# 31/31 - 0s - loss: 0.4559 - accuracy: 0.7950 - 173ms/epoch - 6ms/step
# Epoch 98/200
# 31/31 - 0s - loss: 0.4553 - accuracy: 0.7940 - 174ms/epoch - 6ms/step
# Epoch 99/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7940 - 178ms/epoch - 6ms/step
# Epoch 100/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.7940 - 189ms/epoch - 6ms/step
# Epoch 101/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7940 - 199ms/epoch - 6ms/step
# Epoch 102/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7940 - 194ms/epoch - 6ms/step
# Epoch 103/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.7940 - 190ms/epoch - 6ms/step
# Epoch 104/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7940 - 187ms/epoch - 6ms/step
# Epoch 105/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7919 - 194ms/epoch - 6ms/step
# Epoch 106/200
# 31/31 - 0s - loss: 0.4554 - accuracy: 0.7908 - 199ms/epoch - 6ms/step
# Epoch 107/200
# 31/31 - 0s - loss: 0.4553 - accuracy: 0.7908 - 182ms/epoch - 6ms/step
# Epoch 108/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7919 - 174ms/epoch - 6ms/step
# Epoch 109/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7919 - 183ms/epoch - 6ms/step
# Epoch 110/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7919 - 185ms/epoch - 6ms/step
# Epoch 111/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7919 - 180ms/epoch - 6ms/step
# Epoch 112/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7919 - 182ms/epoch - 6ms/step
# Epoch 113/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7929 - 172ms/epoch - 6ms/step
# Epoch 114/200
# 31/31 - 0s - loss: 0.4555 - accuracy: 0.7908 - 186ms/epoch - 6ms/step
# Epoch 115/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7919 - 173ms/epoch - 6ms/step
# Epoch 116/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7908 - 176ms/epoch - 6ms/step
# Epoch 117/200
# 31/31 - 0s - loss: 0.4557 - accuracy: 0.7919 - 181ms/epoch - 6ms/step
# Epoch 118/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7919 - 173ms/epoch - 6ms/step
# Epoch 119/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7919 - 178ms/epoch - 6ms/step
# Epoch 120/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7919 - 179ms/epoch - 6ms/step
# Epoch 121/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7940 - 192ms/epoch - 6ms/step
# Epoch 122/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7940 - 178ms/epoch - 6ms/step
# Epoch 123/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7940 - 181ms/epoch - 6ms/step
# Epoch 124/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7940 - 178ms/epoch - 6ms/step
# Epoch 125/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7940 - 180ms/epoch - 6ms/step
# Epoch 126/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7981 - 184ms/epoch - 6ms/step
# Epoch 127/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7981 - 171ms/epoch - 6ms/step
# Epoch 128/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7971 - 184ms/epoch - 6ms/step
# Epoch 129/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7960 - 170ms/epoch - 5ms/step
# Epoch 130/200
# 31/31 - 0s - loss: 0.4548 - accuracy: 0.7960 - 170ms/epoch - 5ms/step
# Epoch 131/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7960 - 178ms/epoch - 6ms/step
# Epoch 132/200
# 31/31 - 0s - loss: 0.4547 - accuracy: 0.7971 - 180ms/epoch - 6ms/step
# Epoch 133/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7908 - 181ms/epoch - 6ms/step
# Epoch 134/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7908 - 197ms/epoch - 6ms/step
# Epoch 135/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7971 - 205ms/epoch - 7ms/step
# Epoch 136/200
# 31/31 - 0s - loss: 0.4547 - accuracy: 0.7940 - 196ms/epoch - 6ms/step
# Epoch 137/200
# 31/31 - 0s - loss: 0.4563 - accuracy: 0.7888 - 193ms/epoch - 6ms/step
# Epoch 138/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7929 - 207ms/epoch - 7ms/step
# Epoch 139/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7929 - 193ms/epoch - 6ms/step
# Epoch 140/200
# 31/31 - 0s - loss: 0.4548 - accuracy: 0.7929 - 181ms/epoch - 6ms/step
# Epoch 141/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7908 - 188ms/epoch - 6ms/step
# Epoch 142/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7908 - 181ms/epoch - 6ms/step
# Epoch 143/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7908 - 185ms/epoch - 6ms/step
# Epoch 144/200
# 31/31 - 0s - loss: 0.4551 - accuracy: 0.7919 - 187ms/epoch - 6ms/step
# Epoch 145/200
# 31/31 - 0s - loss: 0.4553 - accuracy: 0.7888 - 198ms/epoch - 6ms/step
# Epoch 146/200
# 31/31 - 0s - loss: 0.4559 - accuracy: 0.7919 - 262ms/epoch - 8ms/step
# Epoch 147/200
# 31/31 - 0s - loss: 0.4550 - accuracy: 0.7908 - 181ms/epoch - 6ms/step
# Epoch 148/200
# 31/31 - 0s - loss: 0.4547 - accuracy: 0.7929 - 169ms/epoch - 5ms/step
# Epoch 149/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7940 - 202ms/epoch - 7ms/step
# Epoch 150/200
# 31/31 - 0s - loss: 0.4546 - accuracy: 0.7940 - 212ms/epoch - 7ms/step
# Epoch 151/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7940 - 263ms/epoch - 8ms/step
# Epoch 152/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7940 - 186ms/epoch - 6ms/step
# Epoch 153/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7940 - 183ms/epoch - 6ms/step
# Epoch 154/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7950 - 191ms/epoch - 6ms/step
# Epoch 155/200
# 31/31 - 0s - loss: 0.4546 - accuracy: 0.7981 - 179ms/epoch - 6ms/step
# Epoch 156/200
# 31/31 - 0s - loss: 0.4552 - accuracy: 0.7981 - 209ms/epoch - 7ms/step
# Epoch 157/200
# 31/31 - 0s - loss: 0.4547 - accuracy: 0.7981 - 210ms/epoch - 7ms/step
# Epoch 158/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7960 - 228ms/epoch - 7ms/step
# Epoch 159/200
# 31/31 - 0s - loss: 0.4553 - accuracy: 0.7981 - 187ms/epoch - 6ms/step
# Epoch 160/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7981 - 191ms/epoch - 6ms/step
# Epoch 161/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7971 - 181ms/epoch - 6ms/step
# Epoch 162/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7950 - 181ms/epoch - 6ms/step
# Epoch 163/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7950 - 180ms/epoch - 6ms/step
# Epoch 164/200
# 31/31 - 0s - loss: 0.4547 - accuracy: 0.7960 - 180ms/epoch - 6ms/step
# Epoch 165/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7919 - 178ms/epoch - 6ms/step
# Epoch 166/200
# 31/31 - 0s - loss: 0.4546 - accuracy: 0.7919 - 186ms/epoch - 6ms/step
# Epoch 167/200
# 31/31 - 0s - loss: 0.4546 - accuracy: 0.7919 - 183ms/epoch - 6ms/step
# Epoch 168/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7908 - 176ms/epoch - 6ms/step
# Epoch 169/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7929 - 182ms/epoch - 6ms/step
# Epoch 170/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7908 - 190ms/epoch - 6ms/step
# Epoch 171/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7908 - 174ms/epoch - 6ms/step
# Epoch 172/200
# 31/31 - 0s - loss: 0.4548 - accuracy: 0.7898 - 182ms/epoch - 6ms/step
# Epoch 173/200
# 31/31 - 0s - loss: 0.4548 - accuracy: 0.7908 - 179ms/epoch - 6ms/step
# Epoch 174/200
# 31/31 - 0s - loss: 0.4546 - accuracy: 0.7919 - 184ms/epoch - 6ms/step
# Epoch 175/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7919 - 180ms/epoch - 6ms/step
# Epoch 176/200
# 31/31 - 0s - loss: 0.4546 - accuracy: 0.7940 - 199ms/epoch - 6ms/step
# Epoch 177/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7940 - 210ms/epoch - 7ms/step
# Epoch 178/200
# 31/31 - 0s - loss: 0.4543 - accuracy: 0.7940 - 211ms/epoch - 7ms/step
# Epoch 179/200
# 31/31 - 0s - loss: 0.4543 - accuracy: 0.7950 - 192ms/epoch - 6ms/step
# Epoch 180/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7940 - 208ms/epoch - 7ms/step
# Epoch 181/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7940 - 213ms/epoch - 7ms/step
# Epoch 182/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7940 - 210ms/epoch - 7ms/step
# Epoch 183/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7919 - 192ms/epoch - 6ms/step
# Epoch 184/200
# 31/31 - 0s - loss: 0.4549 - accuracy: 0.7929 - 213ms/epoch - 7ms/step
# Epoch 185/200
# 31/31 - 0s - loss: 0.4547 - accuracy: 0.7960 - 217ms/epoch - 7ms/step
# Epoch 186/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7929 - 200ms/epoch - 6ms/step
# Epoch 187/200
# 31/31 - 0s - loss: 0.4543 - accuracy: 0.7940 - 189ms/epoch - 6ms/step
# Epoch 188/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7950 - 180ms/epoch - 6ms/step
# Epoch 189/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7940 - 186ms/epoch - 6ms/step
# Epoch 190/200
# 31/31 - 0s - loss: 0.4542 - accuracy: 0.7940 - 188ms/epoch - 6ms/step
# Epoch 191/200
# 31/31 - 0s - loss: 0.4543 - accuracy: 0.7940 - 220ms/epoch - 7ms/step
# Epoch 192/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7940 - 197ms/epoch - 6ms/step
# Epoch 193/200
# 31/31 - 0s - loss: 0.4543 - accuracy: 0.7940 - 191ms/epoch - 6ms/step
# Epoch 194/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7940 - 211ms/epoch - 7ms/step
# Epoch 195/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7940 - 193ms/epoch - 6ms/step
# Epoch 196/200
# 31/31 - 0s - loss: 0.4545 - accuracy: 0.7960 - 187ms/epoch - 6ms/step
# Epoch 197/200
# 31/31 - 0s - loss: 0.4541 - accuracy: 0.7919 - 190ms/epoch - 6ms/step
# Epoch 198/200
# 31/31 - 0s - loss: 0.4544 - accuracy: 0.7908 - 188ms/epoch - 6ms/step
# Epoch 199/200
# 31/31 - 0s - loss: 0.4538 - accuracy: 0.7908 - 184ms/epoch - 6ms/step
# Epoch 200/200
# 31/31 - 0s - loss: 0.4539 - accuracy: 0.7940 - 177ms/epoch - 6ms/step
